# %%
import pandas as pd

# %%
product_map = pd.read_excel("..\Product_Map.xlsx")
hedge_trades = pd.read_excel("..\or_cost_only37.5%_withProductMapping.xlsx")

# %%
pd.read_csv("..\poll_input\output_USD.csv")
# Out:
#        CCY             TradeType                                         Firm  \
# 0      USD      Vanilla Outright  Average of 5th, 6th and 7th smallest charge
# 1      USD      Vanilla Outright  Average of 5th, 6th and 7th smallest charge
# 2      USD      Vanilla Outright  Average of 5th, 6th and 7th smallest charge
# 3      USD      Vanilla Outright  Average of 5th, 6th and 7th smallest charge
# 4      USD      Vanilla Outright  Average of 5th, 6th and 7th smallest charge
# 5      USD      Vanilla Outright  Average of 5th, 6th and 7th smallest charge
# 6      USD      Vanilla Outright  Average of 5th, 6th and 7th smallest charge
# 7      USD      Vanilla Outright  Average of 5th, 6th and 7th smallest charge
# 8      USD      Vanilla Outright  Average of 5th, 6th and 7th smallest charge
# 9      USD      Vanilla Outright  Average of 5th, 6th and 7th smallest charge
# 10     USD      Vanilla Outright  Average of 5th, 6th and 7th smallest charge
# 11     USD      Vanilla Outright  Average of 5th, 6th and 7th smallest charge
# 12     USD      Vanilla Outright  Average of 5th, 6th and 7th smallest charge
# 13     USD      Vanilla Outright  Average of 5th, 6th and 7th smallest charge
# 14     USD      Vanilla Outright  Average of 5th, 6th and 7th smallest charge
# 15     USD      Vanilla Outright  Average of 5th, 6th and 7th smallest charge
# 16     USD      Vanilla Outright  Average of 5th, 6th and 7th smallest charge
# 17     USD      Vanilla Outright  Average of 5th, 6th and 7th smallest charge
# 18     USD      Vanilla Outright  Average of 5th, 6th and 7th smallest charge
# 19     USD      Vanilla Outright  Average of 5th, 6th and 7th smallest charge
# 20     USD      Vanilla Outright  Average of 5th, 6th and 7th smallest charge
# 21     USD      Vanilla Outright  Average of 5th, 6th and 7th smallest charge
# 22     USD      Vanilla Outright  Average of 5th, 6th and 7th smallest charge
# 23     USD      Vanilla Outright  Average of 5th, 6th and 7th smallest charge
# 24     USD      Vanilla Outright  Average of 5th, 6th and 7th smallest charge
# 25     USD      Vanilla Outright  Average of 5th, 6th and 7th smallest charge
# 26     USD      Vanilla Outright  Average of 5th, 6th and 7th smallest charge
# 27     USD      Vanilla Outright  Average of 5th, 6th and 7th smallest charge
# 28     USD      Vanilla Outright  Average of 5th, 6th and 7th smallest charge
# 29     USD      Vanilla Outright  Average of 5th, 6th and 7th smallest charge
# ...    ...                   ...                                          ...
# 10914  USD  Zero Coupon Outright                                         BBVA
# 10915  USD  Zero Coupon Outright                                         BBVA
# 10916  USD  Zero Coupon Outright                                         BBVA
# 10917  USD  Zero Coupon Outright                                         BBVA
# 10918  USD  Zero Coupon Outright                                         BBVA
# 10919  USD  Zero Coupon Outright                                         BBVA
# 10920  USD  Zero Coupon Outright                                         BBVA
# 10921  USD  Zero Coupon Outright                                         BBVA
# 10922  USD  Zero Coupon Outright                                         BBVA
# 10923  USD  Zero Coupon Outright                                         BBVA
# 10924  USD  Zero Coupon Outright                                         BBVA
# 10925  USD  Zero Coupon Outright                                         BBVA
# 10926  USD  Zero Coupon Outright                                         BBVA
# 10927  USD  Zero Coupon Outright                                         BBVA
# 10928  USD  Zero Coupon Outright                                         BBVA
# 10929  USD  Zero Coupon Outright                                         BBVA
# 10930  USD  Zero Coupon Outright                                         BBVA
# 10931  USD  Zero Coupon Outright                                         BBVA
# 10932  USD  Zero Coupon Outright                                         BBVA
# 10933  USD  Zero Coupon Outright                                         BBVA
# 10934  USD  Zero Coupon Outright                                         BBVA
# 10935  USD  Zero Coupon Outright                                         BBVA
# 10936  USD  Zero Coupon Outright                                         BBVA
# 10937  USD  Zero Coupon Outright                                         BBVA
# 10938  USD  Zero Coupon Outright                                         BBVA
# 10939  USD  Zero Coupon Outright                                         BBVA
# 10940  USD  Zero Coupon Outright                                         BBVA
# 10941  USD  Zero Coupon Outright                                         BBVA
# 10942  USD  Zero Coupon Outright                                         BBVA
# 10943  USD  Zero Coupon Outright                                         BBVA
#
#               Size Tenor              Spread
# 0        2000000.0  3m**  1.2222222222222223
# 1        5000000.0  3m**                 2.0
# 2       10000000.0  3m**  3.6666666666666665
# 3       20000000.0  3m**                 5.0
# 4       50000000.0  3m**   7.666666666666667
# 5      100000000.0  3m**                12.0
# 6        2000000.0  6m**  1.6666666666666667
# 7        5000000.0  6m**  2.1666666666666665
# 8       10000000.0  6m**                 4.0
# 9       20000000.0  6m**   5.666666666666667
# 10      50000000.0  6m**   7.666666666666667
# 11     100000000.0  6m**                12.0
# 12       2000000.0    1Y                1.75
# 13       5000000.0    1Y  2.1666666666666665
# 14      10000000.0    1Y   4.333333333333333
# 15      20000000.0    1Y   6.666666666666667
# 16      50000000.0    1Y                 8.5
# 17     100000000.0    1Y                14.0
# 18       2000000.0    2Y                 2.0
# 19       5000000.0    2Y  2.6666666666666665
# 20      10000000.0    2Y   4.666666666666667
# 21      20000000.0    2Y   6.666666666666667
# 22      50000000.0    2Y   8.833333333333334
# 23     100000000.0    2Y  14.666666666666666
# 24       2000000.0    5Y                 2.0
# 25       5000000.0    5Y  2.6999999999999997
# 26      10000000.0    5Y   4.666666666666667
# 27      20000000.0    5Y   7.833333333333333
# 28      50000000.0    5Y  10.166666666666666
# 29     100000000.0    5Y  16.666666666666668
# ...            ...   ...                 ...
# 10914    -400000.0    1Y                 2.0
# 10915   -1000000.0    1Y                 6.0
# 10916   -2000000.0    1Y                15.0
# 10917   -4000000.0    1Y                33.0
# 10918  -10000000.0    1Y                 NaN
# 10919  -20000000.0    1Y                 NaN
# 10920    -400000.0    2Y                 2.0
# 10921   -1000000.0    2Y                 6.0
# 10922   -2000000.0    2Y                15.0
# 10923   -4000000.0    2Y                33.0
# 10924  -10000000.0    2Y                 NaN
# 10925  -20000000.0    2Y                 NaN
# 10926    -400000.0    5Y                 2.0
# 10927   -1000000.0    5Y                 6.0
# 10928   -2000000.0    5Y                15.0
# 10929   -4000000.0    5Y                33.0
# 10930  -10000000.0    5Y                 NaN
# 10931  -20000000.0    5Y                 NaN
# 10932    -400000.0   10Y                 2.0
# 10933   -1000000.0   10Y                 6.0
# 10934   -2000000.0   10Y                15.0
# 10935   -4000000.0   10Y                33.0
# 10936  -10000000.0   10Y                 NaN
# 10937  -20000000.0   10Y                 NaN
# 10938    -400000.0   30Y                 4.0
# 10939   -1000000.0   30Y                12.0
# 10940   -2000000.0   30Y                25.0
# 10941   -4000000.0   30Y                50.0
# 10942  -10000000.0   30Y                 NaN
# 10943  -20000000.0   30Y                 NaN
#
# [10944 rows x 6 columns]

# %%
path='..\poll_input'

def find_csv_filenames( path_to_dir, suffix=".csv" ):
    filenames = listdir(path_to_dir)
    return [ filename for filename in filenames if filename.endswith( suffix ) ]

filenames = find_csv_filenames(path)

for name in filenames:
    if 'WTA' in name in name:
        wta_names.append(name)
    if 'Dutch' in name in name:
        dutch_names.append(name)
